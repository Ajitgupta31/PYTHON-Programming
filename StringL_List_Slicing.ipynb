# %% [markdown]
# **String List  slicing(datatype)**

# %%
s1 ='nit'
s1
# Out:
# 'nit'

# %%
s1[0]
# Out:
# 'n'

# %%
s1[2]
# Out:
# 't'

# %%
s1[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_15747/3229368127.py in <cell line: 0>()
# ----> 1 s1[4]
#
# IndexError: string index out of range

# %%
s1
# Out:
# 'nit'

# %%
for i in s1:
  print(s1)
  print(i)
# Out:
# nit
# n
# nit
# i
# nit
# t

# %% [markdown]
# List Slicing

# %%
a=[20,48,28,78,98,65]
b=[56,78,'Ajit',True]

# %%
print(a)
print(b)
# Out:
# [20, 48, 28, 78, 98, 65]
# [56, 78, 'Ajit', True]

# %%
a[:]
# Out:
# [20, 48, 28, 78, 98, 65]

# %%
a[0:4]
# Out:
# [20, 48, 28, 78]

# %%
a[2:]
# Out:
# [28, 78, 98, 65]

# %%
a[:6]
# Out:
# [20, 48, 28, 78, 98, 65]

# %%
a[0:20:3]
# Out:
# [20, 78]

# %%
a[2:10:3]
# Out:
# [28, 65]

# %%
a
# Out:
# [20, 48, 28, 78, 98, 65]

# %%
a[::-1]
# Out:
# [65, 98, 78, 28, 48, 20]

# %%
a[::-2]
# Out:
# [65, 78, 48]

# %%
b[::-3]
# Out:
# [True, 56]

# %%
a
# Out:
# [20, 48, 28, 78, 98, 65]

# %%
a[0]
# Out:
# 20

# %%
a[0]=100
a
# Out:
# [100, 48, 28, 78, 98, 65]

# %%
a[-1] = 'Ajit'
a
# Out:
# [100, 48, 28, 78, 98, 'Ajit']

# %%
a[-1][0] #nested slicing
# Out:
# 'A'

# %%
print(a[-1][0])
print(a[-1][1])
print(a[-1][2])
print(a[-1][3])
# Out:
# A
# j
# i
# t

# %%
c=a+b
c
# Out:
# [100, 48, 28, 78, 98, 'Ajit', 56, 78, 'Ajit', True]

# %% [markdown]
# **List membership**

# %%
48 in a
# Out:
# True

# %% [markdown]
# **Enumerate**

# %%
for i in a:
  print(i)
# Out:
# 100
# 48
# 28
# 78
# 98
# Ajit

# %%
for i in enumerate(a):
  print(i)
# Out:
# (0, 100)
# (1, 48)
# (2, 28)
# (3, 78)
# (4, 98)
# (5, 'Ajit')

# %%
for i in enumerate(a):
  print(a)
# Out:
# [100, 48, 28, 78, 98, 'Ajit']
# [100, 48, 28, 78, 98, 'Ajit']
# [100, 48, 28, 78, 98, 'Ajit']
# [100, 48, 28, 78, 98, 'Ajit']
# [100, 48, 28, 78, 98, 'Ajit']
# [100, 48, 28, 78, 98, 'Ajit']

# %%
all(a)
# Out:
# True

# %%
any(a)
# Out:
# True

# %%
a.append(0)
a
# Out:
# [100, 48, 28, 78, 98, 'Ajit', 0]

# %%
all(a)
# Out:
# False

# %%
any(a)
# Out:
# True
