# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajitgupta31/PYTHON-Programming/blob/main/Python_operator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***PYTHON OPERATOR***

# %% [markdown]
# 1. Arithmatic Operator

# %%
a=7
b=9
print(a+b)
# Out:
# 16

# %%
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)
print(a//b)
# Out:
# -2
# 63
# 0.7777777777777778
# 7
# 40353607
# 0

# %% [markdown]
# 2.Assignment Operator : Assigns the value of the right-hand operand to the left-hand variable.

# %%
x=9
print(x)
# Out:
# 9

# %% [markdown]
# Add Assignment

# %%
x=9
x+=8
print(x)
# Out:
# 17

# %% [markdown]
# Sub Assignment

# %%
x=98
x-=45
print(x)
# Out:
# 53

# %% [markdown]
# Multiple and Assign(*=)

# %%
x=78
x*=89
print(x)
# Out:
# 6942

# %% [markdown]
# Module and Assign(%=)

# %%
x=980
x%=23
print(x)
# Out:
# 14

# %% [markdown]
# floor Division Assignment oprator(//=)

# %%
x=3947
x//=56
print(x)
# Out:
# 70

# %% [markdown]
# Swap Value Assignment

# %%
a=78
b=70
a,b =b,a
print(a,b)
# Out:
# 70 78

# %% [markdown]
# 3.Logical Operator : Logical operators are used to combine conditional statements:
#
# **and** 	Returns True if both statements are true	x < 5 and  x < 10	.
#
# **or**	Returns True if one of the statements is true	x < 5 or x < 4
#
# **not**	Reverse the result, returns False if the result is true	not(x < 5 and x < 10)

# %%
x = 5

print(x > 3 and x < 10)
# Out:
# True

# %%
x = 59

print(x < 3 or x < 50)
# Out:
# False

# %%
is_logged_in = False

# Reverses False to True
if not is_logged_in:
    print("Please log in to continue.")
# Out:
# Please log in to continue.

# %%
age = 25
has_ticket = True
is_banned = False

# 1. 'and' operator: Both conditions must be True
if age >= 18 and has_ticket:
    print("Access granted: You are an adult with a ticket.")

# 2. 'or' operator: At least one condition must be True
day = "Saturday"
if day == "Saturday" or day == "Sunday":
    print("It's the weekend!")

# 3. 'not' operator: Reverses the boolean value
if not is_banned:
    print("You are allowed to enter the venue.")

# 4. Combining operators (Precedence: not > and > or)
# This checks if someone is eligible for a discount:
# Must be (a student OR a senior) AND NOT banned.
is_student = True
is_senior = False

if (is_student or is_senior) and not is_banned:
    print("Discount applied!")
# Out:
# Access granted: You are an adult with a ticket.
# It's the weekend!
# You are allowed to enter the venue.
# Discount applied!

# %% [markdown]
# 4. Bitwise Operator : In Python, bitwise operators perform operations on integers by treating them as sequences of binary bits (0s and 1s). They are primarily used in low-level programming, such as cryptography, performance optimization, and hardware interactions.
#
# Operator 	Name	Description	Example (a=10, b=4)
#
#
# **&	AND**	Sets bit to 1 if both bits are 1.	10 & 4 → 0
#
#
# **|	OR**	Sets bit to 1 if at least one bit is 1.	10 | 4 → 14
#
#
# **^	XOR	**Sets bit to 1 if bits are different.	10 ^ 4 → 14
#
#
# **~	NOT**	Inverts all bits (flips 0 to 1 and vice versa).	~10 → -11
#
#
# **<<**	Left Shift	Shifts bits left, filling with 0s on the right.	10 << 1 → 20
#
#
# **>>**	Right Shift	Shifts bits right, discarding rightmost bits.	10 >> 1 →

# %%
# Values in binary:
# a (10) = 1010
# b (4)  = 0100

a = 10
b = 4

# 1. Bitwise AND: Results in 0000 (0)
print(f"a & b: {a & b}")

# 2. Bitwise OR: Results in 1110 (14)
print(f"a | b: {a | b}")

# 3. Bitwise XOR: Results in 1110 (14)
print(f"a ^ b: {a ^ b}")

# 4. Bitwise NOT: Inverts bits (formula: -(x + 1))
# ~10 results in -11
print(f"~a: {~a}")

# 5. Bitwise Left Shift: 1010 becomes 10100 (20)
# Effectively multiplies by 2^n
print(f"a << 1: {a << 1}")

# 6. Bitwise Right Shift: 1010 becomes 0101 (5)
# Effectively floor divides by 2^n
print(f"a >> 1: {a >> 1}")
# Out:
# a & b: 0
# a | b: 14
# a ^ b: 14
# ~a: -11
# a << 1: 20
# a >> 1: 5

# %% [markdown]
# # 1. Bitwise AND: Results in 0000 (0)
#
# 1 & 1 is 1 rest of themm are 0

# %%
a = 10
b = 4

# 1. Bitwise AND: Results in 0000 (0)
print(f"a & b: {a & b}")
# Out:
# a & b: 0

# %%
12 & 13
# Out:
# 12

# %%
6&9
# Out:
# 0

# %%
8 & 9
# Out:
# 8

# %%
9 & 16
# Out:
# 0

# %%
35 & 33
# Out:
# 33

# %%
35 & 40
# Out:
# 32

# %% [markdown]
# # 2. Bitwise OR: Results in 1110 (14)
#
# 0 & 0 is 0 rest of them are 1

# %%
a=10
b=4

print(f"a | b: {a | b}")
# Out:
# a | b: 14

# %%
54 or 47
# Out:
# 54

# %%
3 or 5
# Out:
# 3

# %%
5 | 4
# Out:
# 5

# %% [markdown]
# # 3. Bitwise XOR: Results in 1110 (14)

# %%
print(f"a ^ b: {a ^ b}")
# Out:
# a ^ b: 14

# %%
12 ^ 13
# Out:
# 1

# %%
20 ^ 30
# Out:
# 10

# %%
25 ^ 30
# Out:
# 7

# %% [markdown]
# # 4. Bitwise NOT: Inverts bits (formula: -(x + 1))
# # ~10 results in -11

# %%
print(f"~a: {~a}")
# Out:
# ~a: -11

# %% [markdown]
# # 5. Bitwise Left Shift: 1010 becomes 10100 (20)
# # Effectively multiplies by 2^n

# %%
a =56
print(f"a << 1: {a << 1}")
# Out:
# a << 1: 112

# %%
10<<1
# Out:
# 20

# %% [markdown]
# 10 = 1010
# left shift by 1 (<<1) means add 0 in binary so it makes 10100 = 20

# %%
10<<2
# Out:
# 40

# %% [markdown]
# 10 = 1010
# left shift by 2 (<<2 ) means add 00 (2 zero add) in binary so it makes 10100 0= 40

# %%
10<<3
# Out:
# 80

# %% [markdown]
# # 6. Bitwise Right Shift: 1010 becomes 0101 (5)
# # Effectively floor divides by 2^n

# %%
print(f"a >> 1: {a >> 1}")
# Out:
# a >> 1: 28

# %%
10>>1
# Out:
# 5

# %%
10>>2
# Out:
# 2

# %%
10>>4
# Out:
# 0

# %%
20>>4
# Out:
# 1

# %% [markdown]
# **Check if number is even or odd using Bitwise**

# %%
x=int(input("Enter the number:"))
if x & 1:
  print("Odd")
else:
  print("Even")
# Out:
# Enter the number:78
# Even

# %% [markdown]
# **Swap two numbers without temp value**

# %%
a=int(input("Enter the value of a:"))
b=int(input("Enter the value of b:"))

a= a ^ b
b= a ^ b
a= a ^ b

print("After swapping:")
print("a=",a)
print("b=",b)
# Out:
# Enter the value of a:79
# Enter the value of b:43
# After swapping:
# a= 43
# b= 79

# %% [markdown]
# **#Find common number for given Value**

# %%
a= [45,78,98,68,68,68,78]
result =0
for num in a:
  result = result ^ num

print(result)
# Out:
# 11

# %% [markdown]
# **5. Comparision Operator **
# Comparison operators (also called relational operators) are used to compare two values. They evaluate the relationship between operands and return a Boolean value:
#
# **either True or False. **

# %%
x = 15
y = 20
name1 = "Ajit"
name2 = "Sonu"

# 1. Basic Equality
print(f"Is x equal to y? {x == y}")       # False

# 2. Inequality
print(f"Is x not equal to y? {x != y}")   # True

# 3. Size Comparisons
print(f"Is x > 10? {x > 10}")             # True
print(f"Is y <= 20? {y <= 20}")           # True

# 4. String Comparison (based on alphabetical order/Unicode)
print(f"Does 'Ajit' come before 'Sonu'? {name1 < name2}") # True

# 5. Chained Comparisons (a unique Python feature)
# Checks if 10 is less than x AND x is less than 20
is_between = 10 < x < 20
print(f"Is 10 < x < 20? {is_between}")    # True
# Out:
# Is x equal to y? False
# Is x not equal to y? True
# Is x > 10? True
# Is y <= 20? True
# Does 'Ajit' come before 'Sonu'? True
# Is 10 < x < 20? True

# %% [markdown]
# 6. IDENTITY OPERATOR :
#
# dentity operators are used to check if two variables point to the exact same object in memory.
# While comparison operators (==) check if values are equal, identity operators (is) check if the memory address (ID) is the same.
#
#
# Operator 	Description	Example
#
# **is**	Returns True if both variables point to the same object.	x is y
#
#
# **is not**	Returns True if variables point to different objects.	x is not y

# %%
# Create two identical lists
list_a = [1, 2, 3]
list_b = [1, 2, 3]
list_c = list_a  # c points to the same object as a

# 1. 'is' vs '=='
# They have the same values, so == is True
print(f"list_a == list_b: {list_a == list_b}")  # True

# They are different objects in memory, so 'is' is False
print(f"list_a is list_b: {list_a is list_b}")  # False

# 2. Assigning the same object
# list_c was set to list_a, so they share the same ID
print(f"list_a is list_c: {list_a is list_c}")  # True

# 3. 'is not' operator
print(f"list_a is not list_b: {list_a is not list_b}") # True

# 4. Checking Memory Addresses
print(f"ID of a: {id(list_a)}")
print(f"ID of b: {id(list_b)}")
# Out:
# list_a == list_b: True
# list_a is list_b: False
# list_a is list_c: True
# list_a is not list_b: True
# ID of a: 133681658696448
# ID of b: 133681658696128

# %% [markdown]
# 7. MEMBERSHIP OPERATOR :
# Membership operators are used to test whether a value or variable is found within a sequence, such as a string, list, tuple, set, or dictionary.
#
# Operator	Description	Example
#
#
# **in**	Returns True if the value is present in the sequence.	'a' in 'apple'
#
#
# **not in**	Returns True if the value is not present in the sequence.	'z' not in 'apple'

# %%
# 1. Using 'in' with a List
fruits = ["apple", "banana", "cherry"]
print(f"Is 'apple' in fruits? {'apple' in fruits}")     # True

# 2. Using 'not in' with a String
message = "Hello World"
print(f"Is 'z' not in message? {'z' not in message}")   # True

# 3. Membership in Dictionaries
# Note: This checks KEYS by default, not values.
user_data = {"name": "Alice", "age": 25}

print(f"Is 'name' in user_data? {'name' in user_data}") # True
print(f"Is 'Alice' in user_data? {'Alice' in user_data}") # False (Alice is a value)

# 4. In a conditional statement
guest_list = ["Bob", "Charlie", "David"]
current_user = "Eve"

if current_user not in guest_list:
    print(f"Access denied: {current_user} is not on the list.")
# Out:
# Is 'apple' in fruits? True
# Is 'z' not in message? True
# Is 'name' in user_data? True
# Is 'Alice' in user_data? False
# Access denied: Eve is not on the list.

# %% [markdown]
# #  Compliment (~)
#
# 12 == 1100 ||
#
#
#
# *   first thing we need to understand what is mean bt complement
# *   Compliment means it will do reverse of the binary formate  i.e .. 0 it will give you 1 ~1 it will give you 0
#
#
# *   12 binary formate is ~00001100 reverse the number - 11110011 which is (-13)
# *   in the virtual memory we can not store -ve number & the only way to store the -ve value by using complimentory
#
#
#
# *   # why we got -13?
# *   to understand the concept of 2's complement
#
#
#
# *   2's complement means (1's compliment + 1)
# *   List item
#
#
#
#
#
#
#
#
#
# In heap memory -- never store negative number
#
# thats reason if we are using compliment this way to store -ve value in RAM

# %%
~12
# Out:
# -13

# %%
~56
# Out:
# -57

# %% [markdown]
# # Import MATH Function

# %%
import math

# %%
x = math.sqrt(33)
x
# Out:
# 5.744562646538029

# %%
print(math.floor(3.87))
# Out:
# 3

# %%
print(math.ceil(3.87))
# Out:
# 4

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.e) # epsilon value
# Out:
# 2.718281828459045

# %%
from math import sqrt , pow, floor, ceil
print(pow(2,3))
print(floor(3.87))
print(sqrt(3))
print(ceil(3.5))
# Out:
# 8.0
# 3
# 1.7320508075688772
# 4

# %%
from math import *
print(pow(2,3))
print(floor(3.87))
print(sqrt(3))
print(ceil(3.5))
# Out:
# 8.0
# 3
# 1.7320508075688772
# 4
