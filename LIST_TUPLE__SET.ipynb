# %% [markdown]
# LIST : List items are order in nature.
#
#
# :- a list is a built-in data type used to store multiple items in a single variable. It is the most versatile and frequently used collection type because it is changeable
#
#
#
# **Key Characteristics**
#
# **Ordered:** Items have a specific order that stays the same unless you change it.
#
#
# **Mutable**: You can add, remove, or modify items after the list is created.
#
#
# **Allow Duplicates:** Since items are indexed, you can have multiple identical values.
#
#
# **Dynamic:** They can grow or shrink in size as needed.
#
#
# **Basic Syntax**
#
# Lists are written with square brackets []

# %%
a= [2,4,"Ajit","Suman","Gupta"]
print(a[2:4])
# Out:
# ['Ajit', 'Suman']

# %%
a.append("Sonu")
print(a)
# Out:
# [2, 4, 'Ajit', 'Suman', 'Gupta', 'Sonu']

# %% [markdown]
# REMOVE THE LIST

# %%
a.remove(4)
print(a)
# Out:
# [2, 'Ajit', 'Suman', 'Gupta', 'Sonu']

# %%
a.pop()
# Out:
# 'Sonu'

# %%
a.pop(2)
print(a)
# Out:
# [2, 'Ajit', 'Gupta']

# %% [markdown]
# #Delete the entire list

# %%
del a

# %%
#Itteration over elements

# %%
a= [2,3,"Ajit","Gupta",7,9,True]

for n in a[2:4] :
  print(a)
# Out:
# [2, 3, 'Ajit', 'Gupta', 7, 9, True]
# [2, 3, 'Ajit', 'Gupta', 7, 9, True]

# %% [markdown]
# LIST COMPREHENSION
#
# #it basically offers a shorter sysntax

# %%
Ajit = ["Ajit","xyz"]
p=[item for item in Ajit  if 'a'in item.lower()]

print(p)

#for i in Ajit:
# p.append(i)
#print(p)
# Out:
# ['Ajit']

# %% [markdown]
# **Sorting and Reversing The List**

# %%
A= ["Apple","Mango","Mnc","xyz"]

#for item.lower() in A :
 # print(item)

A= [i.lower()for i in A]

print(A)
# Out:
# ['apple', 'mango', 'mnc', 'xyz']

# %%
prices = [45.99, 12.50, 100.0, 5.25]

prices.sort()          # Changes original list to [5.25, 12.5, 45.99, 100.0]
print(prices)
prices.reverse()       # Flips the order

print(prices)
# Out:
# [5.25, 12.5, 45.99, 100.0]
# [100.0, 45.99, 12.5, 5.25]

# %% [markdown]
# **Slicing**
#
# You can extract a portion of a list using the [start:stop:step]
#
# syntax:

# %%
numbers = [0, 1, 2, 3, 4, 5]
print(numbers[1:4])  # Output: [1, 2, 3] (index 1 to 3)
print(numbers[::-1])
# Out:
# [1, 2, 3]
# [5, 4, 3, 2, 1, 0]

# %%
colors = ["red", "green", "blue", "yellow", "purple"]

print(colors[1:4])  # (Index 1 to 3)
print(colors[:2])   # (First two)
print(colors[-1])   # (Last item)
# Out:
# ['green', 'blue', 'yellow']
# ['red', 'green']
# purple

# %% [markdown]
# 2. **Adding and Removing Items**
#
#
#
# Lists are mutable, so you can change their size and content easily.

# %%
tasks = ["Email boss", "Buy milk"]

# Add to the end
tasks.append("Gym")

# Insert at a specific spot (index 1)
tasks.insert(1, "Clean kitchen")

# Remove a specific item
tasks.remove("Buy milk")

# Remove by index (returns the removed item)
last_task = tasks.pop()

print(tasks)
# Out:
# ['Email boss', 'Clean kitchen']

# %% [markdown]
# 3. **List Comprehensions (The "Pro" Way)**
#
#
# This is a concise way to create a new list based on an existing one.

# %%
numbers = [1, 2, 3, 4, 5]

# Square every number in the list
squares = [n**2 for n in numbers]
print(squares) # Output: [1, 4, 9, 16, 25]

# Create a list of even numbers only
evens = [n for n in numbers if n % 2 == 0]
print(evens)
# Out:
# [1, 4, 9, 16, 25]
# [2, 4]

# %% [markdown]
# 5. **Iterating with Index (enumerate)**
#
#
# If you need both the item and its position while looping:

# %%
winners = ["Alice", "Bob", "Charlie"]

for index, name in enumerate(winners, start=1):
    print(f"Rank {index}: {name}")
# Out:
# Rank 1: Alice
# Rank 2: Bob
# Rank 3: Charlie

# %% [markdown]
# **Tuple**
#
# #Identification :- (.....,....,....)

# %%
a=(3,5,"Ajit")
print(type(a))
# Out:
# <class 'tuple'>

# %% [markdown]
# Tuple : A tuple in Python is a built-in data type used to store a collection of items in a single variable. It is an ordered, immutable (unchangeable), and indexed sequence.
#
# Tuple Iteam are
#
# 1. ordered iteam as list with small breaket
#
# 2. Immutable: Once created, you cannot add, remove, or change items.
#
# 3. Duplicate is allowed here
#
# 4. Heterogeneous: A single tuple can hold different data types, such as strings, integers, and even lists.
#
#
#
# **Basic Operations:**
#
# Creation: Define items inside parentheses () separated by commas.
#
#   1.Single-item Tuple: Requires a trailing comma, e.g., my_tuple = ("apple",).
#
#
# Accessing Items: Use square brackets [] with an index starting at 0.
#
#   1. Negative Indexing: -1 refers to the last item.
#
#
# Slicing: Access a range of items using tuple[start:stop:step].
#
#
# Packing & Unpacking: Assigning values to a tuple is "packing," while extracting them into variables is "unpacking

# %%
fruits = ("apple", "banana", "cherry", "banana")

print(fruits[0])
print(fruits.count("banana"))
# Out:
# apple
# 2

# %% [markdown]
# 2. **Unpacking Tuples**
#
#
# You can "unpack" the elements of a tuple directly into variables. This is a very common Pythonic pattern.

# %%
point = (10, 20, 30)
x, y, z = point

print(f"x: {x}, y: {y}, z: {z}")
# Out:
# x: 10, y: 20, z: 30

# %% [markdown]
# 3.** Returning Multiple Values from a Function**
#
#
# Functions often return tuples when they need to provide more than one result.

# %%
def user():
    return "Alice", 25, "Engineer"

name, age, job = user()
print(name)
print(age)
print(job)
# Out:
# Alice
# 25
# Engineer

# %% [markdown]
# 4. **Using Tuples as Dictionary Keys**
# **bold text**
#
#
# Because tuples are immutable, they can be used as keys in a dictionary, whereas lists cannot.

# %%
locations_Capital = {
    ("India"): "New Delhi",
    (34.0522, -118.2437): "Los Angeles"
}

print(locations_Capital[("India")])
print(locations_Capital[(34.0522, -118.2437)])
# Out:
# New Delhi
# Los Angeles

# %% [markdown]
# 5. **Swapping Variables**
#
#
#
# Tuples allow you to swap the values of two variables in a single line without a temporary third variable.

# %%
a = 5
b = 10

a, b = b, a
print(f"a: {a}, b: {b}")
# Out:
# a: 10, b: 5

# %% [markdown]
# **SET :**
# a set is a built-in data structure used to store a collection of unique elements in a single variable. It is particularly useful for tasks where you need to eliminate duplicates or perform mathematical set operations.
#
#
#
# **Key Characteristics**
#
# **Unordered**: Elements do not have a defined order, so they may appear differently each time you print the set.
#
#
# **Unique Elements:** Duplicate values are automatically removed. If you add the same item twice, it will only appear once.
#
#
# **Unindexed:** Because they are unordered, you cannot access items by an index (e.g., my_set[0] will raise an error).
#
#
# **Mutable:** You can add or remove items after the set is created, but the individual elements must be immutable (e.g., strings, numbers, or tuples)
#
#
#
# **Basic Usage and Syntax :**
#
# Sets are written with curly brackets {} or created using the set() constructor.

# %%
# Creating a set with duplicates
my_set = {"apple", "banana", "cherry", "apple"}
print(my_set)  # Output: {'banana', 'apple', 'cherry'} (order may vary)

# Creating an empty set (MUST use set(), as {} creates an empty dictionary)
empty_set = set()
# Out:
# {'apple', 'banana', 'cherry'}

# %% [markdown]
# the most common set operations in Python, using both shorthand operators and built-in methods.
#
#
# 1. Basic Set Setup

# %%
set_a = {1, 2, 3, 4, 5}
set_b = {4, 5, 6, 7, 8}

# %% [markdown]
# 2. **Union (All items from both)**
#
# Combines elements from both sets, removing duplicates.

# %%
# Operator: |
union_res = set_a | set_b
# Method: .union()
union_res = set_a.union(set_b)

print(union_res)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %% [markdown]
# 3.** Intersection (Only common items)**
#
#
# Finds only the elements that exist in both sets.

# %%
# Operator: &
intersect_res = set_a & set_b
# Method: .intersection()
intersect_res = set_a.intersection(set_b)

print(intersect_res)
# Out:
# {4, 5}

# %% [markdown]
# 4. **Difference (Unique to one side)**
#
#
# Returns items in the first set that are not in the second.

# %%
# Operator: -
diff_res = set_a - set_b
# Method: .difference()
diff_res = set_a.difference(set_b)

print(diff_res) # Output: {1, 2, 3}
# Out:
# {1, 2, 3}

# %% [markdown]
# 5. **Symmetric Difference (Items NOT in both)**
#
#
# Returns items that are in either set, but not in their intersection.

# %%
# Operator: ^
sym_diff_res = set_a ^ set_b
# Method: .symmetric_difference()
sym_diff_res = set_a.symmetric_difference(set_b)

print(sym_diff_res)
# Out:
# {1, 2, 3, 6, 7, 8}

# %% [markdown]
# 6. **Membership and Modification**

# %%
# Check if item exists (very fast in sets)
if 3 in set_a:
    print("3 is present")

# Adding and Removing
set_a.add(10)        # Adds 10
set_a.remove(1)      # Removes 1 (raises error if missing)
set_a.discard(99)
# Out:
# 3 is present

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
a=[6,8,9]
a.append(10)
a
# Out:
# [6, 8, 9, 10]

# %% [markdown]
# Slicing in List

# %%
a[:]
# Out:
# [6, 8, 9, 10]

# %%
a[1]
# Out:
# 8

# %%
a[-2]
# Out:
# 9

# %%
b=a.copy()
b
# Out:
# [6, 8, 9, 10]

# %%
a==b
# Out:
# True

# %%
print(len(a))
print(len(b))
# Out:
# 4
# 4

# %%
b.append(3.8)
b.append(True)
b.append(2+3j)
b
# Out:
# [6, 8, 9, 10, 3.8, True, (2+3j)]

# %%
a.count(10)
# Out:
# 1

# %%
b.count(True)
# Out:
# 1

# %%
a.count(34)
# Out:
# 0

# %%
a
# Out:
# [6, 8, 9, 10]

# %%
b

# %%
c=b.copy()
c
# Out:
# [6, 8, 9, 10, 3.8, True, (2+3j)]

# %%
c.remove(True)
c
# Out:
# [6, 8, 9, 10, 3.8, (2+3j)]

# %%
c.remove(3.8)
c
# Out:
# [6, 8, 9, 10, (2+3j)]

# %%
d=c.copy()
d
# Out:
# [6, 8, 9, 10, (2+3j)]

# %%
d.clear()
d
# Out:
# []

# %%
x=6
x
# Out:
# 6

# %%
x
# Out:
# 6

# %%
_ +7
# Out:
# 13

# %%
_*9
# Out:
# 117

# %%
a= [10,30,26,24,76,87,]

# %%
for i in a:
  print(a)
# Out:
# [10, 30, 26, 24, 76, 87]
# [10, 30, 26, 24, 76, 87]
# [10, 30, 26, 24, 76, 87]
# [10, 30, 26, 24, 76, 87]
# [10, 30, 26, 24, 76, 87]
# [10, 30, 26, 24, 76, 87]

# %%
a.append([3,6,"ajit"]) #nested list
a
# Out:
# [10, 30, 26, 24, 76, 87, [3, 6, 'ajit']]

# %%
a =[10, 30, 26, 24, 76, 87, [3, 6, 'ajit']]

a.append(26)
a
# Out:
# [10, 30, 26, 24, 76, 87, [3, 6, 'ajit'], 26]

# %%
a.pop()
a
# Out:
# [10, 30, 26, 24, 76, 87, [3, 6, 'ajit']]

# %%
a.pop(-3)
a.append(30)
a
# Out:
# [10, 30, 26, 24, 87, [3, 6, 'ajit'], 30]

# %%
a.remove(30)
a
# Out:
# [10, 26, 24, 87, [3, 6, 'ajit'], 30]

# %%
a.insert(3,35)
a
# Out:
# [10, 26, 24, 35, 87, [3, 6, 'ajit'], 30]

# %%
a.insert(1,15)
a
# Out:
# [10, 15, 26, 24, 35, 87, [3, 6, 'ajit'], 30]

# %%
x=[]
x
# Out:
# []

# %%
x.extend(a)
x
# Out:
# [10, 15, 26, 24, 35, 87, [3, 6, 'ajit'], 30]

# %%
a.extend(x)
a
# Out:
# [10,
#  15,
#  26,
#  24,
#  35,
#  87,
#  [3, 6, 'ajit'],
#  30,
#  10,
#  15,
#  26,
#  24,
#  35,
#  87,
#  [3, 6, 'ajit'],
#  30,
#  10,
#  15,
#  26,
#  24,
#  35,
#  87,
#  [3, 6, 'ajit'],
#  30]

# %%
print(x)
print(a)
# Out:
# [10, 15, 26, 24, 35, 87, [3, 6, 'ajit'], 30]
# [10, 15, 26, 24, 35, 87, [3, 6, 'ajit'], 30, 10, 15, 26, 24, 35, 87, [3, 6, 'ajit'], 30, 10, 15, 26, 24, 35, 87, [3, 6, 'ajit'], 30]

# %%
x.index(26)
# Out:
# 2

# %%
x.remove
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_13077/3219350806.py in <cell line: 0>()
# ----> 1 x.remove(3)
#       2 x
#
# ValueError: list.remove(x): x not in list

# %%
a= [10,30,26,24,76,87,]
a.sort()
a
# Out:
# [10, 24, 26, 30, 76, 87]

# %%
a.sort(reverse=True) #decending order
a
# Out:
# [87, 76, 30, 26, 24, 10]

# %%
a.reverse()
a
# Out:
# [10, 24, 26, 30, 76, 87]

# %%
a[::-1]
a
# Out:
# [10, 24, 26, 30, 76, 87]
